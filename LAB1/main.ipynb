# %% [markdown]
# # LAB 1 Izhikevich features
#
# Author: Aliprandi Francesco

# %%
import matplotlib.pyplot as plt
import numpy as np

from utils import izhikevich, plot_and_save_imgs

# %%
# note: this conditions helds for (A), (B), (C), (D), (E), (F), (G), (H)
condition = lambda t, T1: t > T1

# %% [markdown]
# ## (A) tonic spiking

# %%
pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.2, 
    c = -65, 
    d = 6, 
    current = 14,
    u = -70,
    condition=condition,
    w = -1,
    tau = 0.25,
    max_t = 100,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(A) tonic spiking")

# %% [markdown]
# ## (B) phasic spiking

# %%
pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.25, 
    c = -65, 
    d = 6, 
    current = 0.5,
    u = -64,
    condition=condition,
    w = -1,
    tau = 0.25,
    max_t = 200,
    T1 = 20,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(B) phasic spiking")

# %% [markdown]
# ## (C) tonic bursting

# %%
pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.2, 
    c = -50, 
    d = 2, 
    current = 15,
    u = -70,
    condition=condition,
    w = -1,
    tau = 0.25,
    max_t = 220,
    T1 = 22,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(C) tonic spiking")

# %% [markdown]
# ## (D) phasic bursting

# %%
pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.25, 
    c = -55, 
    d = 0.05, 
    current = 0.6,
    u = -64,
    condition=condition,
    w = -1,
    tau = 0.2,
    max_t = 200,
    T1 = 20,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(D) phasic bursting")

# %% [markdown]
# ## (E) mixed mode

# %%
pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.2, 
    c = -55, 
    d = 4, 
    current = 10,
    u = -70,
    condition=condition,
    w = -1,
    tau = 0.25,
    max_t = 160,
    T1 = -1,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(E) mixed mode")

# %% [markdown]
# ## (F) spike frequency adaptation

# %%
pot, rec, tspan = izhikevich(
    a = 0.01, 
    b = 0.2, 
    c = -65, 
    d = 8, 
    current = 30,
    u = -70,
    condition=condition,
    w = -1,
    tau = 0.25,
    max_t = 85,
    T1 = -1,
    equalize = True
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(F) spike frequency adaptation")

# %% [markdown]
# ## (G) Class 1 excitable

# %%
current_eq = lambda t, T1: 0.075 * (t - T1) #used to cumpute the current value

pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = -0.1, 
    c = -55, 
    d = 6, 
    current = -1, 
    u = -60,
    condition=condition,
    current_eq=current_eq,
    w = -1,
    tau = 0.25,
    max_t = 300,
    T1 = 30,
    equalize = True,
    current_type = "linear",
    beta = 0,     # default value for input current
    u2 = 4.1,
    u3 = 108
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(G) Class 1 excitable")

# %% [markdown]
# ## (H) Class 2 excitable

# %%
current_eq = lambda t, T1: -0.5 + (0.015 * (t - T1)) #used to cumpute the current value

pot, rec, tspan = izhikevich(
    a = 0.2, 
    b = 0.26, 
    c = -65, 
    d = 0, 
    current = -1,
    u = -64,
    condition=condition,
    w = -1,
    T1 = 30,
    tau = 0.25,
    max_t = 300,
    equalize = True,
    current_type = "linear",
    current_eq=current_eq,
    beta = -0.5,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(H) Class 2 excitable")

# %% [markdown]
# ## (I) spike latency

# %%
condition = lambda t, T1: t > T1 and t < T1+3

pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = 0.2, 
    c = -65, 
    d = 6, 
    current = 7.04, 
    condition = condition,
    u = -70,
    w = -1,
    tau = 0.2,
    max_t = 100,
    equalize = True,
    beta = 0
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(I) spike latency")

# %% [markdown]
# ## (J) subthreshold oscillations

# %%
condition = lambda t, T1: t > T1 and t < T1+5 

pot, rec, tspan = izhikevich(
    a = 0.05, 
    b = 0.26, 
    c = -60, 
    d = 0, 
    current = 2, 
    condition = condition,
    u = -62,
    w = -1,
    tau = 0.25,
    max_t = 200,
    equalize = True,
    beta = 0,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(J) subthreshold oscillations")

# %% [markdown]
# ## (K) resonator

# %%
condition = lambda t, T1: ((t>T1) and (t < T1+4)) or ((t>T1 + 20) and (t < T1 + 24)) or ((t>0.7 * tspan[-1]) and (t < (0.7 * tspan[-1])+4)) or ((t>(0.7 * tspan[-1]) + 40) and (t < (0.7 * tspan[-1]) + 44)) 

pot, rec, tspan = izhikevich(
    a = 0.1, 
    b = 0.26, 
    c = -60, 
    d = -1, 
    current = 0.65, 
    current_type="step",
    condition = condition,
    u = -62,
    w = -1,
    tau = 0.25,
    max_t = 400,
    equalize = True,
    beta=0
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(K) resonator")

# %% [markdown]
# ## (L) integrator

# %%
condition = lambda t, T1: ((t>T1) and (t < T1+2)) or ((t>T1+5) and (t < T1+7)) or ((t>0.7*tspan[-1]) and (t <0.7*tspan[-1]+2)) or ((t>0.7*tspan[-1]+10) and (t < 0.7*tspan[-1]+12))

pot, rec, tspan = izhikevich(
    a = 0.02, 
    b = -0.1, 
    c = -55, 
    d = 6, 
    current = 9, 
    condition = condition,
    u = -60,
    w = -1,
    tau = 0.25,
    max_t = 100,
    T1 = 100/11,
    equalize = True,
    beta = 0,
    u2 = 4.1,
    u3 = 108
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(L) integrator")

# %% [markdown]
# ## (M) rebound spike

# %%
condition = lambda t, T1: (t>T1) and (t < T1+5)
pot, rec, tspan = izhikevich(
    a = 0.03, 
    b = 0.25, 
    c = -60, 
    d = 4, 
    current = -15, 
    condition = condition,
    u = -64,
    w = -1,
    tau = 0.2,
    max_t = 200,
    equalize = True,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(M) rebound spike")

# %% [markdown]
# ## (N) rebound burst

# %%
condition = lambda t, T1: (t>T1) and (t < T1+5)

pot, rec, tspan = izhikevich(
    a = 0.03, 
    b = 0.25, 
    c = -52, 
    d = 0, 
    current = -15, 
    condition = condition,
    u = -64,
    w = -1,
    tau = 0.2,
    max_t = 200,
    equalize = True,
    beta = 0,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(N) rebound burst")

# %% [markdown]
# ## (O) threshold variability

# %%
pot, rec, tspan = izhikevich(
    a = 0.03,
    b = 0.25,
    c = -60,
    d = 4,
    current = -1,
    condition = None,
    u = -64,
    w = -1,
    tau = 0.25,
    max_t = 100,
    equalize = True,
    current_type= "thr_var",
    feature = "(O)",
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(O) threshold variability")

# %% [markdown]
# ## (P) bistability

# %%
condition = lambda t, T1: ((t>T1) and (t < T1+5)) or ((t>216) and (t < 221))

pot, rec, tspan = izhikevich(
    a = 0.1,
    b = 0.26,
    c = -60,
    d = 0,
    current = 1.24,
    condition = condition,
    u = -61,
    w = -1,
    tau = 0.25,
    max_t = 300,
    T1 = 300/8,
    equalize = True,
    current_type= "step",
    beta = 0.24
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(P) bistability")

# %% [markdown]
# ## (Q) Depolarising After-Potential

# %%
condition = lambda t, T1:np.abs(t-T1)<1

pot, rec, tspan = izhikevich(
    a = 1,
    b = 0.2,
    c = -60,
    d = -21,
    current = 20,
    condition = condition,
    u = -70,
    w = -1,
    tau = 0.1,
    max_t = 50,
    T1 = 10,
    equalize = True,
    current_type= "step",
    beta = 0,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(Q) Depolarising After-Potential")

# %% [markdown]
# ## (R) accomodation

# %%
pot, rec, tspan = izhikevich(
    a = 0.02,
    b = 1,
    c = -55,
    d = 4,
    current = -1,
    condition = None,
    u = -65,
    w = -16,
    tau = 0.5,
    max_t = 400,
    equalize = True,
    current_type= "thr_var",
    feature="(R)",
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(R) accomodation")

# %% [markdown]
# ## (S) inhibition induced spiking

# %%
condition = lambda t, T1: (t < 50) or (t>250)

pot, rec, tspan = izhikevich(
    a = -0.02,
    b = -1,
    c = -60,
    d = 8,
    current = 80,
    condition = condition,
    u = -63.8,
    w = -1,
    tau = 0.5,
    max_t = 350,
    equalize = True,
    current_type= "step",
    beta = 75,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(S) inhibition induced spiking")

# %% [markdown]
# ## (T) inhibition induced bursting

# %%
condition = lambda t, T1: (t < 50) or (t>250)

pot, rec, tspan = izhikevich(
    a = -0.026,
    b = -1,
    c = -45,
    d = -2,
    current = 80,    
    condition = condition,
    u = -63.8,
    w = -1,
    tau = 0.5,
    max_t = 350,
    equalize = True,
    current_type= "step",
    beta = 75,
    )

# %%
plot_and_save_imgs(pot, rec, tspan, title = "(T) inhibition induced bursting")
